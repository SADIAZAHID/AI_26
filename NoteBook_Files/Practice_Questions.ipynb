# %% [markdown]
# # Student Grade Functions

# %%
def Calculator(a,b,c,d,e):
    
sub1=int(input("Enter Your Subject 1 Marks"))
sub2=int(input("Enter Your Subject 2 Marks"))
sub3=int(input("Enter Your Subject 3 Marks"))
sub4=int(input("Enter Your Subject 4 Marks"))
sub5=int(input("Enter Your Subject 5 Marks"))


sum=a+b+c+d+e
avg =sum/5

def grade(avg):
    if(avg>=90):
        print("A")
    if(avg>=80):
        print("B")
    if(avg>=60):
        print("C")
    if(avg>=50):
        print("D")
# Out:
#   Cell In[19], line 3
#     sub1=int(input("Enter Your Subject 1 Marks"))
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
Avg(50,80,90,70,50)
# Out:
# your Avg Percentage is 68.0

# %%
Avg(40,50,60,70,80)
# Out:
# your Avg Percentage is 60.0

# %%
Sum(40,50,60,70,80)
# Out:
# your Total Marks are 300

# %%
def Number_Analyzer(num):
    if(num>0):
        print("number is positive")
    elif(num<0):
        print("Number is negative")
    else(num=0):
        print("number is zero")
# Out:
#   Cell In[20], line 1
#     def Number_Analyzer(num):
#                              ^
# _IncompleteInputError: incomplete input
