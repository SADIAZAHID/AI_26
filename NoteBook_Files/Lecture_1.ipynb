# %% [markdown]
# # Python Fundamental

# %%
name = "Sadia"
age = 70
gender = 'F'
marks =75.5
is_pass = True
failed_sub = None

# %%
type(name),type(age),type(marks),type(is_pass),type(failed_sub)
# Out:
# (str, int, float, bool, NoneType)

# %%
print("Hello Sadia")
# Out:
# Hello Sadia

# %%
print(name)
# Out:
# Sadia

# %%
print("Hello",name)
# Out:
# Hello Sadia

# %%
print("Hello",name,"wow! you are alive")
# Out:
# Hello Sadia wow! you are alive

# %%
print("My name is ",name,". I am ",age,"years old. Gender",gender,"My marks are ",marks,"My passing status is ",is_pass)
# Out:
# My name is  Sadia . I am  70 years old. Gender F My marks are  75.5 My passing status is  True

# %%
print(f"My name is {name} and I am {age} years old")
# Out:
# My name is Sadia and I am 70 years old

# %%
print("My name is ",end=" ")
print(name,end =" ")
print("I am ",end=" ")
print(age,end=" ")
print("years old",end=" ")
# Out:
# My name is  Sadia I am  70 years old

# %%
Age_1="I am 70 years old"
print(Age_1)
# Out:
# I am 70 years old

# %%
height='I am 5.5" tall'
print(height)
print('I am 5.5" tall')
# Out:
# I am 5.5" tall
# I am 5.5" tall

# %% [markdown]
# # List

# %%
names =['ali','ahmed','umer']
ages =[12,13,14]
marks =[45,58,60]

# %%
data_1=['ali',12,45]
data_1
# Out:
# ['ali', 12, 45]

# %%
type(data_1)
# Out:
# list

# %%
names,ages,marks
# Out:
# (['ali', 'ahmed', 'umer'], [12, 13, 14], [45, 58, 60])

# %% [markdown]
# ![](Images/list.png)

# %% [markdown]
# ## List indexing and list Slicing

# %%
nums=[1,2,3,4,5,6,7,8 ]

# %%
nums[0]
# Out:
# 1

# %%
nums[3:6]
# Out:
# [4, 5, 6]

# %%
num[:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 num[:]
#
# NameError: name 'num' is not defined

# %%
nums[:]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
nums.append(77)

# %%
nums.sort()

# %%
print(nums)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 77]

# %%
nums.insert(1,99)

# %%
print(nums)
# Out:
# [1, 99, 99, 2, 3, 4, 5, 6, 7, 8, 77]

# %%
nums.insert(0,88)

# %%
print(nums)
# Out:
# [88, 1, 99, 99, 2, 3, 4, 5, 6, 7, 8, 77]

# %%
nums.remove(99)

# %%
print(nums)
# Out:
# [88, 1, 99, 2, 3, 4, 5, 6, 7, 8, 77]

# %%
nums.pop(1)
# Out:
# 1

# %%
print(nums)
# Out:
# [88, 99, 2, 3, 4, 5, 6, 7, 8, 77]

# %%
#count,sort,reverse

# %%
nums=[1,2,3]

# %% [markdown]
# nums.pop()

# %%
print(nums)
# Out:
# [1, 2, 3]

# %%
nums.pop(1)
# Out:
# 2

# %%
nums.count(1)
# Out:
# 1

# %%
nums=[1,1,1,1,1,1,1,1,1]

# %%
nums.count(1)
# Out:
# 9

# %%
nums=[2,6,9,0,6,8,4,1]

# %% [raw]
# nums.sort()

# %%
nums.sort()

# %% [markdown]
#  # String

# %%
name="sadia"

# %%
name[1:4]
# Out:
# 'adi'

# %% [markdown]
# ## tip

# %%
name=["sadia","sara","zara"]

# %%
name[1][2]
# Out:
# 'r'

# %% [markdown]
# # Dictionary

# %% [markdown]
# ![](images/dic.png)

# %%
data={
    'name':"Ali",
    'age': 12,
    'marks': 87.5
}

# %%
names=["Sadia","Sara","Ali","Ahmed","Zara"]
ages=[70,21,23,44,18]
gender=['F','F','M','M','F']
marks=[90,80,70,60,50]

data={
    "Name":names,
    "Age":ages,
    "Gender":gender,
    "Marks":marks
}
data
# Out:
# {'Name': ['Sadia', 'Sara', 'Ali', 'Ahmed', 'Zara'],
#  'Age': [70, 21, 23, 44, 18],
#  'Gender': ['F', 'F', 'M', 'M', 'F'],
#  'Marks': [90, 80, 70, 60, 50]}

# %%
data['Age']
# Out:
# [70, 21, 23, 44, 18]

# %%
len(data)
# Out:
# 4

# %%
len(data['Age'])
# Out:
# 5

# %% [markdown]
# ## Comman Function in dictionary

# %%
data.values()
# Out:
# dict_values([['Sadia', 'Sara', 'Ali', 'Ahmed', 'Zara'], [70, 21, 23, 44, 18], ['F', 'F', 'M', 'M', 'F'], [90, 80, 70, 60, 50]])

# %%
data.keys()
# Out:
# dict_keys(['Name', 'Age', 'Gender', 'Marks'])

# %%
data.items()
# Out:
# dict_items([('Name', ['Sadia', 'Sara', 'Ali', 'Ahmed', 'Zara']), ('Age', [70, 21, 23, 44, 18]), ('Gender', ['F', 'F', 'M', 'M', 'F']), ('Marks', [90, 80, 70, 60, 50])])

# %% [markdown]
# # Set

# %%
names=(["sadia",1,2,1])

# %%
print(names)
# Out:
# ['sadia', 1, 2, 1]

# %%
6&7
# Out:
# 6

# %%
6&3
# Out:
# 2
