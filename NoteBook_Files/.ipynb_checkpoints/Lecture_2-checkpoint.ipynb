# %% [markdown]
# # Lec 02:Python Fundamental

# %% [markdown]
# # Operators

# %% [markdown]
# ## Arithematic Operator

# %%
a,b=3,5
a+b,a-b,a*b,a/b,a%b,a**b,a//b
# Out:
# (8, -2, 15, 0.6, 3, 243, 0)

# %%
a,b,c,d,e,f=3,5,9,8,6,5
a+b-c*e**f/d
# Out:
# -8740.0

# %% [markdown]
# ## Logical Operator

# %%
a,b=1,2
a>b and a<b
# Out:
# False

# %%
a>b or b>a
# Out:
# True

# %% [markdown]
# ## Assignment operator

# %%
a=2

# %%
b=a

# %%
print(b)
# Out:
# 2

# %%
a+=b

# %%
a=a+3

# %%
print(a)
# Out:
# 7

# %%
6&7
# Out:
# 6

# %% [markdown]
# # Input

# %%
age=input("enter your age")
type(age)
# Out:
# enter your age 12
# str

# %%
age=int(input("enter your age"))
type(age)
# Out:
# enter your age 23
# int

# %% [markdown]
# # Errors in Python

# %% [markdown]
# ## Syntax Error

# %%
print("Hello
# Out:
#   Cell In[21], line 1
#     print("Hello
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("hello")
# Out:
# hello

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
"5"+3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 "5"+3
#
# TypeError: can only concatenate str (not "int") to str

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %%
lst=[1,2,3]
print(lst[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 lst=[1,2,3]
# ----> 2 print(lst[5])
#
# IndexError: list index out of range

# %%
try:
# Out:
#   Cell In[30], line 1
#     try:
#         ^
# _IncompleteInputError: incomplete input

# %% [markdown]
# ## Exceptional Handling

# %%
try:
    age=int(input("enter your age"))
                  
except:
  print("kindly add digits only")
# Out:
# enter your age aa
# kindly add digits only

# %%
try:
    a=10
    b=int(input("enter a number"))
    c=a/b
    print("Result:",c)
except ZeroDivisionError:
    print("Can't divide by zero")
except ValueError:
    print("Invalid Input :please enter a valid number")
except Exception as e:
    print("An error occurred",e)
else:
    print("No error ,Program executed sucessfully")
finally:
    print("This block is always excuted")
# Out:
# enter a number 36
# Result: 0.2777777777777778
# No error ,Program executed sucessfully
# This block is always excuted
